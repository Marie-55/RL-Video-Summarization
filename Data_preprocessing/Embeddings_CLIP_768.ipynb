# %%
# ============================================================
# CELL 1 — Mount Drive & Install dependencies
# ============================================================
from google.colab import drive
drive.mount('/content/drive')

# openai/CLIP official package
# !pip install -q git+https://github.com/openai/CLIP.git
# Out:
# Mounted at /content/drive
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
#   Building wheel for clip (setup.py) ... done

# %%
# ============================================================
# CELL 2 — Configuration
# ============================================================
import os

BASE_DATASET = '/content/drive/MyDrive/Video_Sum_Dataset'

# All three dataset folders (matching your screenshot)
FRAMES_ROOTS = {
    'Activity':  os.path.join(BASE_DATASET, 'Activity/frames'),
    'Animals':   os.path.join(BASE_DATASET, 'Animals/frames'),
    'Incidents': os.path.join(BASE_DATASET, 'Incidents/frames'),
}

EMBEDDINGS_ROOT = os.path.join(BASE_DATASET, 'embeddings_clip')
os.makedirs(EMBEDDINGS_ROOT, exist_ok=True)

BATCH_SIZE = 64   # frames per GPU batch — lower if you get OOM
DEVICE = 'cuda'   # Colab T4/A100 — will fall back to cpu automatically

# %%
# ============================================================
# CELL 3 — Load CLIP ViT-L/14 (dim=768)
# ============================================================
import torch
import clip

device = torch.device(DEVICE if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# ViT-L/14 is the CLIP variant that produces 768-dim visual embeddings.
# clip.load() downloads weights once (~890 MB) and returns:
#   model      — the full CLIP model (we only use the visual encoder)
#   preprocess — the official preprocessing transform for this variant
model, preprocess = clip.load('ViT-L/14', device=device)
model.eval()

# Quick sanity check on the output dimension
with torch.no_grad():
    dummy = torch.zeros(1, 3, 224, 224).to(device)
    dim = model.encode_image(dummy).shape[-1]

print(f"\u2713 CLIP ViT-L/14 loaded")
print(f"  Output embedding dim : {dim}")
print(f"  Parameters           : {sum(p.numel() for p in model.parameters())/1e6:.0f}M")
# Out:
# Using device: cuda
# 100%|███████████████████████████████████████| 890M/890M [00:17<00:00, 52.9MiB/s]
# ✓ CLIP ViT-L/14 loaded
#   Output embedding dim : 768
#   Parameters           : 428M

# %%
# ============================================================
# CELL 4 — Define preprocessing & embedding extraction
# ============================================================
import torch
import numpy as np
from PIL import Image
import glob

# 'preprocess' was already returned by clip.load() in Cell 3.
# It handles: Resize(224) → CenterCrop(224) → ToTensor → Normalize
# using the exact mean/std CLIP was trained with — no manual config needed.

def load_image_batch(paths):
    """Load a list of image paths into a batched tensor using CLIP's preprocess."""
    tensors = []
    valid_paths = []
    for p in paths:
        try:
            img = Image.open(p).convert('RGB')
            tensors.append(preprocess(img))
            valid_paths.append(p)
        except Exception as e:
            print(f"  \u26a0 Skipping {os.path.basename(p)}: {e}")
    if not tensors:
        return None, []
    return torch.stack(tensors), valid_paths


@torch.no_grad()
def extract_embeddings_for_video(frame_dir, batch_size=64):
    """
    Given a folder of frames (frame_0001.jpg, ...),
    returns:
        embeddings : np.ndarray of shape (N, 768)  — L2-normalised CLIP features
        frame_names: list of N filenames (sorted)
    """
    frame_paths = sorted(glob.glob(os.path.join(frame_dir, '*.jpg')))
    if not frame_paths:
        return None, []

    all_embeddings = []
    all_names = []

    for i in range(0, len(frame_paths), batch_size):
        batch_paths = frame_paths[i:i + batch_size]
        batch_tensor, valid_paths = load_image_batch(batch_paths)
        if batch_tensor is None:
            continue

        batch_tensor = batch_tensor.to(device)

        # encode_image returns the visual CLS embedding: (B, 768)  float32
        # We L2-normalise so cosine similarity = dot product downstream.
        features = model.encode_image(batch_tensor)          # (B, 768)
        features = features / features.norm(dim=-1, keepdim=True)  # L2-normalise
        all_embeddings.append(features.cpu().float().numpy())
        all_names.extend([os.path.basename(p) for p in valid_paths])

    if not all_embeddings:
        return None, []

    return np.vstack(all_embeddings), all_names  # (N, 768)

# %%
# ============================================================
# CELL 5 — Main loop: iterate all folders, save .npz per video
# ============================================================
import time

total_videos = 0
total_frames = 0
skipped = 0

for category, frames_root in FRAMES_ROOTS.items():
    if not os.path.exists(frames_root):
        print(f"\n\u26a0 Frames folder not found, skipping: {frames_root}")
        continue

    print(f"\n{'='*60}")
    print(f"  Category: {category}")
    print(f"  Frames root: {frames_root}")
    print(f"{'='*60}")

    # Each sub-folder = one video
    video_dirs = sorted([
        d for d in os.listdir(frames_root)
        if os.path.isdir(os.path.join(frames_root, d))
    ])

    print(f"  Found {len(video_dirs)} video folders\n")

    # Mirror folder structure: embeddings_clip/<Category>/<video_name>.npz
    category_emb_dir = os.path.join(EMBEDDINGS_ROOT, category)
    os.makedirs(category_emb_dir, exist_ok=True)

    for video_name in video_dirs:
        out_path = os.path.join(category_emb_dir, f"{video_name}.npz")

        # Skip if already computed
        if os.path.exists(out_path):
            existing = np.load(out_path)
            skipped += 1
            print(f"  [SKIP] {video_name} ({existing['embeddings'].shape[0]} frames already embedded)")
            continue

        frame_dir = os.path.join(frames_root, video_name)
        t0 = time.time()

        embeddings, frame_names = extract_embeddings_for_video(frame_dir, BATCH_SIZE)

        if embeddings is None:
            print(f"  [SKIP] {video_name} \u2014 no frames found")
            continue

        # Save as compressed numpy archive
        # Load with: data = np.load('x.npz'); embs = data['embeddings']
        np.savez_compressed(
            out_path,
            embeddings=embeddings,       # shape (N, 768)  float32  L2-normalised
            frame_names=frame_names,     # list of N filenames
            category=category,
            video_name=video_name,
        )

        elapsed = time.time() - t0
        total_videos += 1
        total_frames += len(frame_names)
        print(f"  \u2713 {video_name}: {len(frame_names)} frames \u2192 (N,768) | {elapsed:.1f}s")

print(f"\n{'='*60}")
print(f"DONE")
print(f"  Videos processed     : {total_videos}")
print(f"  Videos skipped       : {skipped} (already existed)")
print(f"  Total frames embedded: {total_frames:,}")
print(f"  Embeddings saved to  : {EMBEDDINGS_ROOT}")
# Out:
# ============================================================
#   Category: Activity
#   Frames root: /content/drive/MyDrive/Video_Sum_Dataset/Activity/frames
# ============================================================
#   Found 77 video folders
#
#   [SKIP] Archery__UCOn2HkJJt8 (370 frames already embedded)
#   [SKIP] Arm_wrestling__A1EflBqBv14 (194 frames already embedded)
#   [SKIP] Assembling_bicycle__BfnM0eyjB5Q (371 frames already embedded)
#   [SKIP] BMX__6uhLrPgbpUA (92 frames already embedded)
#   [SKIP] Baking_cookies__IGcsVPa34Hc (429 frames already embedded)
#   [SKIP] Ballet__c_NlYvL96y0 (250 frames already embedded)
#   [SKIP] Bathing_dog__V90aT-d_FKo (156 frames already embedded)
#   [SKIP] Baton_twirling__dAa10hlgxCY (457 frames already embedded)
#   [SKIP] Beach_soccer__IoGpS8NQklE (464 frames already embedded)
#   [SKIP] Beer_pong__JDg--pjY5gg (252 frames already embedded)
#   [SKIP] Belly_dance__3K62qZ2hGyw (257 frames already embedded)
#   [SKIP] Blow-drying_hair__q6sLCLnTuik (241 frames already embedded)
#   [SKIP] Braiding_hair__qogdv5DWzkQ (443 frames already embedded)
#   [SKIP] Breakdancing__Jifw8dC5yTM (300 frames already embedded)
#   [SKIP] Brushing_hair__fGDVlbI90pw (22 frames already embedded)
#   [SKIP] Building_sandcastles__VRwI8Iydb_o (282 frames already embedded)
#   [SKIP] Bungee_jumping__ZEgmWaMa9PU (459 frames already embedded)
#   [SKIP] Calf_roping__dKiy-7TZqeI (35 frames already embedded)
#   [SKIP] Camel_ride__SokK_O2s9tQ (221 frames already embedded)
#   [SKIP] Canoeing__okvQJRTfGHk (116 frames already embedded)
#   [SKIP] Carving_jack-o-lanterns__-FWGLSfI13Q (446 frames already embedded)
#   [SKIP] Changing_car_wheel__Yk3pQ18So90 (408 frames already embedded)
#   [SKIP] Chopping_wood__xr64cSwpNOM (165 frames already embedded)
#   [SKIP] Clean_and_jerk__XnctHnlJB4g (34 frames already embedded)
#   [SKIP] Cleaning_sink__-5h2E52tl4Q (229 frames already embedded)
#   [SKIP] Cleaning_windows__M1_4oDuh2as (120 frames already embedded)
#   [SKIP] Clipping_cat_claws__NsYBZUTzgDw (66 frames already embedded)
#   [SKIP] Cricket__zLZTqSaGxJo (273 frames already embedded)
#   [SKIP] Croquet__gSH5ya0pfko (194 frames already embedded)
#   [SKIP] Cumbia__WEohpavjsIY (273 frames already embedded)
#   [SKIP] Disc_dog__DU36SNYN-rw (221 frames already embedded)
#   [SKIP] Dodgeball__--0edUL8zmA (184 frames already embedded)
#   [SKIP] Doing_crunches__K8G5CBJtluY (138 frames already embedded)
#   [SKIP] Doing_fencing__SID0y9y6Uk4 (280 frames already embedded)
#   [SKIP] Doing_karate__ZWlwKbuK2fM (349 frames already embedded)
#   [SKIP] Doing_kickboxing__5iQsKA84vWo (311 frames already embedded)
#   [SKIP] Doing_motocross__231pbDe3uQc (22 frames already embedded)
#   [SKIP] Doing_nails__6gZuc4umTPk (466 frames already embedded)
#   [SKIP] Doing_step_aerobics__CLbEvGHmK8k (350 frames already embedded)
#   [SKIP] Drinking_beer__qm1dudWLlUg (36 frames already embedded)
#   [SKIP] Drinking_coffee__4S5ethZhgqs (34 frames already embedded)
#   [SKIP] Drum_corps__YUFPWt0VQ1Y (178 frames already embedded)
#   [SKIP] Elliptical_trainer__MEbEcvzdytY (348 frames already embedded)
#   [SKIP] Fixing_bicycle__4zFiORtQrlA (213 frames already embedded)
#   [SKIP] Fixing_the_roof__xeOHoiH-dmo (373 frames already embedded)
#   [SKIP] Fun_sliding_down__sJFgo9H6zNo (278 frames already embedded)
#   [SKIP] Futsal__0J55EGFLglQ (40 frames already embedded)
#   [SKIP] Getting_a_piercing__0Gr4aKQzGYk (135 frames already embedded)
#   [SKIP] Getting_a_tattoo__BhCNHWQhhEw (383 frames already embedded)
#   [SKIP] Grooming_dog___n9eNF1WaFU (403 frames already embedded)
#   [SKIP] Hammer_throw__dWBnXy2nauU (60 frames already embedded)
#   [SKIP] Hand_car_wash__srXhWAGzd-s (436 frames already embedded)
#   [SKIP] Hand_washing_clothes__V1SEaTS9hos (22 frames already embedded)
#   [SKIP] Hanging_wallpaper__Po6tK3rYE8E (214 frames already embedded)
#   [SKIP] Having_an_ice_cream__h4Cf5u1j0TU (203 frames already embedded)
#   [SKIP] Horseback_riding__M1-G6KEhY-M (260 frames already embedded)
#   [SKIP] Hurling__rs7er4e67ec (215 frames already embedded)
#   [SKIP] Ice_fishing__2GCNxOKMtBo (388 frames already embedded)
#   [SKIP] Installing_carpet__qi_6u0mMJQM (344 frames already embedded)
#   [SKIP] Javelin_throw__NwfosNrFnwk (255 frames already embedded)
#   [SKIP] Kayaking__j_ImkPKoA-U (46 frames already embedded)
#   [SKIP] Kite_flying__WMdeqUyHWSo (260 frames already embedded)
#   [SKIP] Kneeling__PLek2e8NlKc (369 frames already embedded)
#   [SKIP] Laying_tile__ZoKZTceDTLA (330 frames already embedded)
#   [SKIP] Layup_drill_in_basketball__YcDlkZkPb6g (386 frames already embedded)
#   [SKIP] Long_jump__eLJYFoCx-gc (178 frames already embedded)
#   [SKIP] Longboarding__nzjivjnk2Ac (466 frames already embedded)
#   [SKIP] Making_a_cake__a2vaM_aRHv4 (354 frames already embedded)
#   [SKIP] Making_a_lemonade__Z8yNbpjUSLc (333 frames already embedded)
#   [SKIP] Making_a_sandwich__jafEh82XETQ (223 frames already embedded)
#   [SKIP] Making_an_omelette__r2oMItb5EVM (218 frames already embedded)
#   [SKIP] Mixing_drinks__1BfYAuxv6Wk (127 frames already embedded)
#   [SKIP] Mooping_floor__UxlDSfC7S-0 (313 frames already embedded)
#   [SKIP] Mowing_the_lawn__puK4NxGKNdQ (362 frames already embedded)
#   [SKIP] Paintball__8pR6NBu7Ay0 (393 frames already embedded)
#   [SKIP] Painting__-YjGbsbDoxs (325 frames already embedded)
#   [SKIP] Painting_fence__f7qFnCkFIuQ (69 frames already embedded)
#
# ============================================================
#   Category: Animals
#   Frames root: /content/drive/MyDrive/Video_Sum_Dataset/Animals/frames
# ============================================================
#   Found 9 video folders
#
#   [SKIP] Buffaloes (155 frames already embedded)
#   [SKIP] Elephant_ANP (61 frames already embedded)
#   [SKIP] Elephants. CTPHmp4. CTPHmp4. CTPHmp4 (101 frames already embedded)
#   [SKIP] HIPPOPOTAMUS.CTPH (107 frames already embedded)
#   [SKIP] Lions (70 frames already embedded)
#   [SKIP] NO_SOUND_GTFU_Clips- CTPH. Copyright One Health Productions. (25 frames already embedded)
#   [SKIP] Rhinoceros- (158 frames already embedded)
#   [SKIP] Warthog (57 frames already embedded)
#   [SKIP] Zebra (58 frames already embedded)
#
# ============================================================
#   Category: Incidents
#   Frames root: /content/drive/MyDrive/Video_Sum_Dataset/Incidents/frames
# ============================================================
#   Found 43 video folders
#
#   [SKIP] Dirty_Contamined_MnCbTTTi7ic (423 frames already embedded)
#   [SKIP] airplane_accident_kGg6lk4dTnA (641 frames already embedded)
#   [SKIP] bicycle_accident_m2gwFkCU1Q4 (585 frames already embedded)
#   [SKIP] blocked_aPTho-yUGA8 (56 frames already embedded)
#   [SKIP] burned_EwBETGSHdSE (80 frames already embedded)
#   [SKIP] bus_accident_4eH59Ymdm1I (251 frames already embedded)
#   [SKIP] car_accident_yxB029dWEE8 (57 frames already embedded)
#   [SKIP] collapsed_zJiYWm-lFRI (37 frames already embedded)
#   [SKIP] damaged_mmAbFyxZfAc (662 frames already embedded)
#   [SKIP] derecho_tE6leG-Bs18 (43 frames already embedded)
#   [SKIP] drought__nRl6jeD7no (284 frames already embedded)
#   [SKIP] dust_devil_cF4aMbDLLEk (176 frames already embedded)
#   [SKIP] dust_sand_storm_l7MZ5sINwQQ (88 frames already embedded)
#   [SKIP] earthquake_LlqRT2rMFMk (278 frames already embedded)
#   [SKIP] fire_whirl_pap3fXy1IYA (116 frames already embedded)
#   [SKIP] flooded_EQwEnRRE2Bo (266 frames already embedded)
#   [SKIP] fog_Mo9Ws2K4beU (168 frames already embedded)
#   [SKIP] hailstorm_CvrW9SQB54k (412 frames already embedded)
#   [SKIP] heavy_rainfall_KGtGJlDM-DY (23 frames already embedded)
#   [SKIP] ice_storm_dKokGgSj0c8 (373 frames already embedded)
#   [SKIP] landslide_mknStAMia0Q (268 frames already embedded)
#   [SKIP] motorcycle_accident_9em294IeLJ0 (668 frames already embedded)
#   [SKIP] mudslide_mudflow_7q7gDr40h9U (346 frames already embedded)
#   [SKIP] nuclear_explosion_11e8XyUBqRQ (77 frames already embedded)
#   [SKIP] oil_spill_AQqfd9DVMBM (436 frames already embedded)
#   [SKIP] on_fire_JUUn0iXMNAs (175 frames already embedded)
#   [SKIP] rockslide_rockfall_2nvVuRmJmko (94 frames already embedded)
#   [SKIP] ship_accident_0on6Os_A9Oo (300 frames already embedded)
#   [SKIP] sinkhole_2bWQQLQF92s (380 frames already embedded)
#   [SKIP] snow_covered_eu4nKrpoCYQ (268 frames already embedded)
#   [SKIP] snowslide_avalanche_wa9yX4xuCv4 (92 frames already embedded)
#   [SKIP] storm_surge_CvrW9SQB54k (376 frames already embedded)
#   [SKIP] thunderstorm_fAEZa3PqkFk (258 frames already embedded)
#   [SKIP] tornado_Kj9vYIvRdmQ (36 frames already embedded)
#   [SKIP] traffic_jam_uhwobcnhzts (114 frames already embedded)
#   [SKIP] train_accident_ElNoz_Ac2Kk (386 frames already embedded)
#   [SKIP] tropical_cyclone_Bkyod1P6LO0 (243 frames already embedded)
#   [SKIP] truck_accident_VHfjMtKKGAg (108 frames already embedded)
#   [SKIP] under_construction_YwXnUDw5eMk (617 frames already embedded)
#   [SKIP] van_accident_Ks7_YulvGZQ (219 frames already embedded)
#   [SKIP] volcanic_eruption_zXA9RCmZJCY (254 frames already embedded)
#   [SKIP] wildfire_n02ouEgZeNQ (93 frames already embedded)
#   [SKIP] with_smoke_1Z2K6lDt76M (620 frames already embedded)
#
# ============================================================
# DONE
#   Videos processed     : 0
#   Videos skipped       : 129 (already existed)
#   Total frames embedded: 0
#   Embeddings saved to  : /content/drive/MyDrive/Video_Sum_Dataset/embeddings_clip

# %%
# ============================================================
# CELL 6 — Sanity check: load and inspect one embedding file
# ============================================================
import numpy as np
import os

category_emb_dir = os.path.join(EMBEDDINGS_ROOT, 'Incidents')
sample_file = sorted(os.listdir(category_emb_dir))[0]

data = np.load(os.path.join(category_emb_dir, sample_file))

print(f"File       : {sample_file}")
print(f"Embeddings : {data['embeddings'].shape}  (frames x 768)")
print(f"dtype      : {data['embeddings'].dtype}")
print(f"Frames     : {list(data['frame_names'])[:5]} ...")
print(f"Category   : {data['category']}")

# L2 norm should be ~1.0 for every row (sanity check on normalisation)
norms = np.linalg.norm(data['embeddings'], axis=1)
print(f"\nL2 norms   : min={norms.min():.4f}  max={norms.max():.4f}  mean={norms.mean():.4f}  (should all be ~1.0)")

print(f"\nFirst embedding vector (first 8 dims):")
print(data['embeddings'][0, :8])
# Out:
# File       : Dirty_Contamined_MnCbTTTi7ic.npz
# Embeddings : (423, 768)  (frames x 768)
# dtype      : float32
# Frames     : [np.str_('frame_0001.jpg'), np.str_('frame_0002.jpg'), np.str_('frame_0003.jpg'), np.str_('frame_0004.jpg'), np.str_('frame_0005.jpg')] ...
# Category   : Incidents
#
# L2 norms   : min=0.9995  max=1.0005  mean=1.0000  (should all be ~1.0)
#
# First embedding vector (first 8 dims):
# [-0.02845764 -0.01986694  0.01919556 -0.03427124 -0.014328    0.06768799
#  -0.00451279  0.00099277]
